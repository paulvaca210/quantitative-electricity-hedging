# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
path ='C:\Users\vacap\Downloads\european_wholesale_electricity_price_data_hourly\France.csv'
df = pd.read_csv(path)

# %%
df.head()
